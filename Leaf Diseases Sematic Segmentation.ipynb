# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/sun
# Out:
# /content/drive/MyDrive/sun

# %%
#!git clone https://github.com/ultralytics/yolov5.git # clone
# %cd yolov5
# Out:
# /content/drive/MyDrive/sun/yolov5

# %%
pip install -r requirements.txt

# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.2-228-g6ae3dff Python-3.7.15 torch-1.12.1+cu113 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 22.6/107.7 GB disk)

# %%
# !python segment/train.py --img 640 --batch 8 --epochs 100 --data /content/drive/MyDrive/sun/yolov5/sun_leaf-2/data.yaml --weights goa-seg.pt --name sunleaf1
#!python segment/train.py --img 640 --batch 8 --epochs 100 --data /content/drive/MyDrive/sun/yolov5/sun_leaf-2/data.yaml --weights abc-seg.pt --name sunleaf2
#!python segment/train.py --img 640 --batch 8 --epochs 100 --data /content/drive/MyDrive/sun/yolov5/sun_leaf-2/data.yaml --weights dmoa-seg.pt --name sunleaf3
# Out:
# segment/train: weights=yolov5s-seg.pt, cfg=, data=/content/drive/MyDrive/sun/yolov5/sun_leaf-2/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train-seg, name=sunleaf1, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, mask_ratio=4, no_overlap=False
# Command 'git fetch origin' timed out after 5 seconds
# requirements: YOLOv5 requirements "ipython" "thop>=0.1.1" not found, attempting AutoUpdate...
# remote: Enumerating objects: 121, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 121 (delta 73), reused 102 (delta 68), pack-reused 11
# ...

# %%
display.Image(filename=f'runs/train-seg/sunleaf1/results.png', width=1200)

# %%
display.Image(filename=f'runs/train-seg/sunleaf2/results.png', width=1200)

# %%
# !python segment/val.py --weights runs/train-seg/sunleaf1/weights/best.pt --data /content/drive/MyDrive/sun/yolov5/sun_leaf-2/data.yaml --img 640
# Out:
# segment/val: data=/content/drive/MyDrive/sun/yolov5/sun_leaf-2/data.yaml, weights=['runs/train-seg/sunleaf13/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val-seg, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-228-g6ae3dff Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 165 layers, 7406513 parameters, 0 gradients, 25.7 GFLOPs
# val: Scanning '/content/drive/MyDrive/sun/yolov5/sun_leaf-2/valid/labels.cache' images and labels... 22 found, 0 missing, 0 empty, 0 corrupt: 100% 22/22 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:14<00:00, 14.94s/it]
# ...

# %%
display.Image(filename=f'runs/predict-seg/exp1/{example_image_name}', width=600)

# %%
# !python segment/predict.py --img 320 --weights runs/train-seg/sunleaf13/weights/best.pt --source /content/drive/MyDrive/sun/yolov5/scars.jpg
# Out:
# segment/predict: weights=['runs/train-seg/sunleaf13/weights/best.pt'], source=/content/drive/MyDrive/sun/yolov5/scars.jpg, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v6.2-228-g6ae3dff Python-3.7.15 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 165 layers, 7406513 parameters, 0 gradients, 25.7 GFLOPs
# image 1/1 /content/drive/MyDrive/sun/yolov5/scars.jpg: 320x256 13 scarss, 123.5ms
# Speed: 0.5ms pre-process, 123.5ms inference, 0.9ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/predict-seg/exp3

# %%
display.Image(filename=f'runs/predict-seg/exp2/scars.jpg', width=600)
